# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('coldata_nsqip.csv', index_col=0)
data.head()
# Out:
#            SEX         RACE_NEW
# sample
# PB630     Male  Some Other Race  \
# PB447     Male            White
# PB495   Female            White
# PB53      Male            White
# PB269     Male            White
#
#                                                   PRNCPTX    AGE ELECTSURG
# sample
# PB630                Colectomy, partial; with anastomosis  73.68       NaN  \
# PB447   Laparoscopy, surgical; colectomy, total, abdom...  54.12       Yes
# PB495   Laparoscopy, surgical; colectomy, total, abdom...  54.79       Yes
# PB53    Colectomy, total, abdominal, with proctectomy;...  45.29       Yes
# PB269   Laparoscopy, surgical; colectomy, total, abdom...  33.23       Yes
#
#        EMERGNCY             WNDCLAS                 ASACLAS     DIABETES
# sample
# PB630       NaN                 NaN  ASA 3 - Severe Disturb           No  \
# PB447        No  Clean/Contaminated  ASA 3 - Severe Disturb  Non-Insulin
# ...

# %%
pd.crosstab(data['IASC'], data['SSI'], margins=True)
# Out:
# SSI   No  Yes  All
# IASC
# No    90    9   99
# Yes    0   11   11
# All   90   20  110

# %%
data['SSI_IASC'] = np.NaN
data.loc[data['SSI'] == 'No', 'SSI_IASC'] = 'No infection'
data.loc[data['SSI'] == 'Yes', 'SSI_IASC'] = 'SSI'
data.loc[data['IASC'] == 'Yes', 'SSI_IASC'] = 'IASC'
data['SSI_IASC'].value_counts(dropna=False)
# Out:
# SSI_IASC
# No infection    90
# IASC            11
# SSI              9
# Name: count, dtype: int64

# %%
data.to_csv('coldata_nsqip.csv')
